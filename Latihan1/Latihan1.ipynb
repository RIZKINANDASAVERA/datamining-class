# %% [markdown]
# import pandas as pd
# import numpy as np

# %%
## input data
biodata = pd.DataFrame({'NIM': ['1001', '1002', '1003', '1004','1005','1006'],
                     'Gender': ['P', 'P', 'L', 'L','P','L'], # JK=Jenis Kelamin
                     'Usia': ['19', '20', '19', '19','20','20']})

nilai = pd.DataFrame({'NIM': ['1001', '1002', '1003', '1004','1005','1006'],
                      'IPK': ['3.94', '3.34', '3.75', '3.11','3.39','3.56'],
                      'Nilai': ['A', 'AB', 'AB', 'B','AB','AB']})

result1 = pd.merge(biodata, nilai, on='NIM')
result1
# Out:
#     NIM Gender Usia   IPK Nilai
# 0  1001      P   19  3.94     A
# 1  1002      P   20  3.34    AB
# 2  1003      L   19  3.75    AB
# 3  1004      L   19  3.11     B
# 4  1005      P   20  3.39    AB
# 5  1006      L   20  3.56    AB

# %%
## manual tambah data
biodata = pd.DataFrame({'NIM': ['1001', '1002', '1003', '1004','1005','1006','1007','1008'],
                     'Gender': ['P', 'P', 'L', 'L','P','L','P','L'], # JK=Jenis Kelamin
                     'Usia': ['19', '20', '19', '19','20','20','20','19']})

nilai = pd.DataFrame({'NIM': ['1001', '1002', '1003', '1004','1005','1006','1007','1008'],
                      'IPK': ['3.94', '3.34', '3.75', '3.11','3.39','3.56','3.89','3.09'],
                      'Nilai': ['A', 'AB', 'AB', 'B','AB','AB','A','B']})

result2 = pd.merge(biodata, nilai, on='NIM')
result2
# Out:
#     NIM Gender Usia   IPK Nilai
# 0  1001      P   19  3.94     A
# 1  1002      P   20  3.34    AB
# 2  1003      L   19  3.75    AB
# 3  1004      L   19  3.11     B
# 4  1005      P   20  3.39    AB
# 5  1006      L   20  3.56    AB
# 6  1007      P   20  3.89     A
# 7  1008      L   19  3.09     B

# %%
result2 = result2[['NIM', 'Gender', 'Usia', 'Nilai','IPK']]
result2
# Out:
#     NIM Gender Usia Nilai   IPK
# 0  1001      P   19     A  3.94
# 1  1002      P   20    AB  3.34
# 2  1003      L   19    AB  3.75
# 3  1004      L   19     B  3.11
# 4  1005      P   20    AB  3.39
# 5  1006      L   20    AB  3.56
# 6  1007      P   20     A  3.89
# 7  1008      L   19     B  3.09

# %%
## manual tambah variabel
biodata = pd.DataFrame({'NIM': ['1001', '1002', '1003', '1004','1005','1006','1007','1008'],
                        'Semester':['2','4','3','3','4','5','4','3'],
                     'Gender': ['P', 'P', 'L', 'L','P','L','P','L'],
                     'Usia': ['19', '20', '19', '19','20','20','20','19']})

nilai = pd.DataFrame({'NIM': ['1001', '1002', '1003', '1004','1005','1006','1007','1008'],
                       'Semester': ['2','3','2','3','3','4','3','3'],
                      'IPK': ['3.94', '3.34', '3.75', '3.11','3.39','3.56','3.89','3.09'],
                      'Nilai': ['A', 'AB', 'AB', 'B','AB','AB','A','B']})

result3 = pd.merge(biodata, nilai, on='NIM')
result3
# Out:
#     NIM Semester_x Gender Usia Semester_y   IPK Nilai
# 0  1001          2      P   19          2  3.94     A
# 1  1002          4      P   20          3  3.34    AB
# 2  1003          3      L   19          2  3.75    AB
# 3  1004          3      L   19          3  3.11     B
# 4  1005          4      P   20          3  3.39    AB
# 5  1006          5      L   20          4  3.56    AB
# 6  1007          4      P   20          3  3.89     A
# 7  1008          3      L   19          3  3.09     B

# %%
result_left = pd.merge(biodata, nilai, how='left', on=['NIM', 'Semester'])
result_left
# Out:
#     NIM Semester Gender Usia   IPK Nilai
# 0  1001        2      P   19  3.94     A
# 1  1002        4      P   20   NaN   NaN
# 2  1003        3      L   19   NaN   NaN
# 3  1004        3      L   19  3.11     B
# 4  1005        4      P   20   NaN   NaN
# 5  1006        5      L   20   NaN   NaN
# 6  1007        4      P   20   NaN   NaN
# 7  1008        3      L   19  3.09     B

# %%
result_right = pd.merge(biodata, nilai, how='right', on=['NIM', 'Semester'])
result_right
# Out:
#     NIM Semester Gender Usia   IPK Nilai
# 0  1001        2      P   19  3.94     A
# 1  1004        3      L   19  3.11     B
# 2  1008        3      L   19  3.09     B
# 3  1002        3    NaN  NaN  3.34    AB
# 4  1003        2    NaN  NaN  3.75    AB
# 5  1005        3    NaN  NaN  3.39    AB
# 6  1006        4    NaN  NaN  3.56    AB
# 7  1007        3    NaN  NaN  3.89     A

# %%
result_outer = pd.merge(biodata, nilai, how='outer', on=['NIM', 'Semester'])
result_outer
# Out:
#      NIM Semester Gender Usia   IPK Nilai
# 0   1001        2      P   19  3.94     A
# 1   1002        4      P   20   NaN   NaN
# 2   1003        3      L   19   NaN   NaN
# 3   1004        3      L   19  3.11     B
# 4   1005        4      P   20   NaN   NaN
# 5   1006        5      L   20   NaN   NaN
# 6   1007        4      P   20   NaN   NaN
# 7   1008        3      L   19  3.09     B
# 8   1002        3    NaN  NaN  3.34    AB
# 9   1003        2    NaN  NaN  3.75    AB
# 10  1005        3    NaN  NaN  3.39    AB
# 11  1006        4    NaN  NaN  3.56    AB
# 12  1007        3    NaN  NaN  3.89     A

# %%
result_inner = pd.merge(biodata, nilai, how='inner', on=['NIM', 'Semester'])
result_inner
# Out:
#     NIM Semester Gender Usia   IPK Nilai
# 0  1001        2      P   19  3.94     A
# 1  1004        3      L   19  3.11     B
# 2  1008        3      L   19  3.09     B

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                'B': ['B0', 'B1', 'B2', 'B3'],
                'C': ['C0', 'C1', 'C2', 'C3'],
                'D': ['D0', 'D1', 'D2', 'D3']})
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                'B': ['B4', 'B5', 'B6', 'B7'],
                'C': ['C4', 'C5', 'C6', 'C7'],
                'D': ['D4', 'D5', 'D6', 'D7']})
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                'B': ['B8', 'B9', 'B10', 'B11'],
                'C': ['C8', 'C9', 'C10', 'C11'],
                'D': ['D8', 'D9', 'D10', 'D11']})

frames = [df1, df2, df3]
result = pd.concat(frames)
result
# Out:
#      A    B    C    D
# 0   A0   B0   C0   D0
# 1   A1   B1   C1   D1
# 2   A2   B2   C2   D2
# 3   A3   B3   C3   D3
# 0   A4   B4   C4   D4
# 1   A5   B5   C5   D5
# 2   A6   B6   C6   D6
# 3   A7   B7   C7   D7
# 0   A8   B8   C8   D8
# 1   A9   B9   C9   D9
# 2  A10  B10  C10  D10
# 3  A11  B11  C11  D11

# %%
result = pd.concat(frames, keys=['df1', 'df2', 'df3'])
result
# Out:
#          A    B    C    D
# df1 0   A0   B0   C0   D0
#     1   A1   B1   C1   D1
#     2   A2   B2   C2   D2
#     3   A3   B3   C3   D3
# df2 0   A4   B4   C4   D4
#     1   A5   B5   C5   D5
#     2   A6   B6   C6   D6
#     3   A7   B7   C7   D7
# df3 0   A8   B8   C8   D8
#     1   A9   B9   C9   D9
#     2  A10  B10  C10  D10
#     3  A11  B11  C11  D11

# %%
df4 = pd.DataFrame({'B': ['B2', 'B3', 'B6', 'B7'],
                    'D': ['D2', 'D3', 'D6', 'D7'],
                    'F': ['F2', 'F3', 'F6', 'F7']},
                    index=[2, 3, 6, 7])

result = pd.concat([df1, df4], axis=0)
result
# Out:
# C:\Users\L645\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#      A   B    C   D    F
# 0   A0  B0   C0  D0  NaN
# 1   A1  B1   C1  D1  NaN
# 2   A2  B2   C2  D2  NaN
# 3   A3  B3   C3  D3  NaN
# 2  NaN  B2  NaN  D2   F2
# 3  NaN  B3  NaN  D3   F3
# 6  NaN  B6  NaN  D6   F6
# 7  NaN  B7  NaN  D7   F7

# %%
result = pd.concat([df1, df4], axis=1, join='inner')
result
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %%
result = pd.concat([df1, df4], axis=1, join_axes=[df1.index])
result
# Out:
#     A   B   C   D    B    D    F
# 0  A0  B0  C0  D0  NaN  NaN  NaN
# 1  A1  B1  C1  D1  NaN  NaN  NaN
# 2  A2  B2  C2  D2   B2   D2   F2
# 3  A3  B3  C3  D3   B3   D3   F3
